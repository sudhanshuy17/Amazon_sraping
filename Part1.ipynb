# %%
# Part 1

# %%
import pandas as pd 
import numpy as np
import requests
from bs4 import BeautifulSoup

# %%
final = pd.DataFrame()

# %%
final
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range (1, 25):
    headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
    webview = requests.get('https://www.amazon.in/s?k=bags&page={}&crid=2M096C61O4MLT&qid=1675407569&sprefix=ba%2Caps%2C283&ref=sr_pg{}'.format(i,i), headers = headers).text
    soup=BeautifulSoup(webview,'html.parser')
    information = soup.find_all('div', class_= 'sg-col-inner')
#     links = []  for testing purpose
    Product_url =[]
    Product_name=[]
    Product_price=[] 
    Rating = []
    Number_of_reviews = []
    for j in information:
        try:
             for link in soup.find_all('a',class_='a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'):
                Product_url.append(link.get('href'))
        except:
            for link in soup.find_all('a',class_='a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'):
                Product_url.append(np.nan)
        try:
            for name in soup.find_all('span', class_='a-size-medium a-color-base a-text-normal'):
                Product_name.append(name.text.strip())
        except:
            for name in soup.find_all('span', class_='a-size-medium a-color-base a-text-normal'):
                Product_name.append(np.nan)
        try:
            for price in soup.find_all('span', class_='a-price-whole'):
                Product_price.append(price.text.strip())
        except:
            for price in soup.find_all('span', class_='a-price-whole'):
                Product_price.append(np.nan)
        try:
             for rating in soup.find_all('span',class_='a-icon-alt'):
                Rating.append(rating.text.strip())
        except:
            for rating in soup.find_all('span',class_='a-icon-alt'):
                Rating.append(np.nan)
        try:
            for review in soup.find_all('span', class_='a-size-base s-underline-text'):
                Number_of_reviews.append(review.text)
        except:
            for review in soup.find_all('span', class_='a-size-base s-underline-text'):
                Number_of_reviews.append(np.nan)
            
    dataFrame = pd.DataFrame({
    'Url':Product_url,
    'Name':Product_name,
    'Price':Product_price,
    'Ratings':Rating,
    'Reviews':Number_of_reviews
})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14000\1816057593.py in <module>
#      42                 Number_of_reviews.append(np.nan)
#      43
# ---> 44     dataFrame = pd.DataFrame({
#      45     'Url':Product_url,
#      46     'Name':Product_name,
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     634         elif isinstance(data, dict):
#     635             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637         elif isinstance(data, ma.MaskedArray):
#     638             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
# ...

# %%
name = pd.DataFrame(Product_name)

# %%
name
# Out:
#                                                       0
# 0     Tabelito® Volt Casual Waterproof Laptop Backpa...
# 1     URBAN TRIBE Havana 15.6" inch Laptop Backpack ...
# 2     American Tourister 32 Ltrs Black Casual Backpa...
# 3     Wesley Milestone 2.0 Casual Waterproof Laptop ...
# 4     ADISA 15.6 inch Laptop Backpack Office Bag Col...
# ...                                                 ...
# 3547  Half Moon Large 37L Laptop Bag Backpack for me...
# 3548  Lavie Sport Lino Large Size 63 cms Wheel Duffl...
# 3549  EUME Virgo Polyester 29Ltr Laptop Backpack for...
# 3550  HEROZ Hammer Unisex Nylon 45 L Travel Laptop B...
# 3551  Scarters | Ultimate Premium Laptop Backpack fo...
#
# [3552 rows x 1 columns]

# %%
url = pd.DataFrame(Product_url)

# %%
url
# Out:
#                                                       0
# 0     /sspa/click?ie=UTF8&spc=MTozMTgzNjYyNzYwMTE4MT...
# 1     /sspa/click?ie=UTF8&spc=MTozMTgzNjYyNzYwMTE4MT...
# 2     /American-Tourister-AMT-SCH-02/dp/B07CJCGM1M/r...
# 3     /Wesley-Milestone-Waterproof-Backpack-Business...
# 4     /ADISA-Laptop-Backpack-Office-College/dp/B09TP...
# ...                                                 ...
# 5027  /Rucksack-Travel-Backpack-Trekking-Compartment...
# 5028  /Half-Moon-Backpack-Compartment-Reflective/dp/...
# 5029  /Lavie-Sport-Duffle-Luggage-Trolley/dp/B097RJ2...
# 5030  /sspa/click?ie=UTF8&spc=MTozMTgzNjYyNzYwMTE4MT...
# 5031  /sspa/click?ie=UTF8&spc=MTozMTgzNjYyNzYwMTE4MT...
#
# [5032 rows x 1 columns]

# %%
price = pd.DataFrame(Product_price)

# %%
price
# Out:
#            0
# 0     5,590.
# 1     5,590.
# 2     5,590.
# 3        599
# 4        998
# ...      ...
# 6211     849
# 6212     999
# 6213   1,448
# 6214   1,424
# 6215  12,399
#
# [6216 rows x 1 columns]

# %%
rating = pd.DataFrame(Rating)

# %%
rating
# Out:
#                        0
# 0     4.9 out of 5 stars
# 1     3.9 out of 5 stars
# 2     4.1 out of 5 stars
# 3     4.3 out of 5 stars
# 4     3.9 out of 5 stars
# ...                  ...
# 5915  4.6 out of 5 stars
# 5916        4 Stars & Up
# 5917        3 Stars & Up
# 5918        2 Stars & Up
# 5919         1 Star & Up
#
# [5920 rows x 1 columns]

# %%
review = pd.DataFrame(Number_of_reviews)
review
# Out:
#            0
# 0         38
# 1        684
# 2     51,370
# 3      9,226
# 4        462
# ...      ...
# 5323   2,127
# 5324   5,790
# 5325     495
# 5326   7,643
# 5327     145
#
# [5328 rows x 1 columns]

# %%
# here we can se the row size of the data columns are different in each column,
# may be this because Amazon website may have more products in one page and less in the other page 
# or may they have the same class name of other products which are come in the suggestions

# %%
result = pd.concat([url, name, price, rating, review], axis=1, join='outer')

# %%
result.isnull().sum()
# Out:
# 0    1184
# 0    2664
# 0       0
# 0     296
# 0     888
# dtype: int64

# %%
result.columns = ['Product_url', 'Product_name', 'Product_price', 'Ratings', 'Number of reviews']

# %%
result.sample(10)
# Out:
#                                             Product_url  \
# 848   /sspa/click?ie=UTF8&spc=MTozMTgzNjYyNzYwMTE4MT...
# 1442  /Fiesto-Fashion-Womens-Handbag-FIESTO33_Blue/d...
# 161   /Wesley-Milestone-Waterproof-Backpack-Business...
# 2081  /Wesley-Milestone-Waterproof-Backpack-Business...
# 2043  /Wesley-Milestone-Waterproof-Backpack-Business...
# 1333  /Wesley-Milestone-Waterproof-Backpack-Business...
# 1391  /Lavie-Sport-Duffle-Luggage-Trolley/dp/B097RJ2...
# 3628  /Blue-Tree-Synthetic-Cartton-Minnie/dp/B07CXXY...
# 1739  /Skybags-Brat-Black-Casual-Backpack/dp/B08Z1HH...
# 4198  /Lapis-Lupo-Flower-Embroidery-Handbag/dp/B07RX...
#
#                                            Product_name Product_price  \
# 848   Wesley Unisex Milestone Casual Waterproof Lapt...           225
# 1442  American Tourister 32 Ltrs Black Casual Backpa...           599
# 161   Lunar's Bingo - 48 L Laptop Office/School/Trav...           899
# ...

# %%
result.to_csv("FinalPart1.csv")
# there are some NaN values ....

# %%
df = pd.read_csv('FinalPart1.csv')

# %%
df.head(10)
# Out:
#    Unnamed: 0                                        Product_url  \
# 0           0  /sspa/click?ie=UTF8&spc=MTozMTgzNjYyNzYwMTE4MT...
# 1           1  /sspa/click?ie=UTF8&spc=MTozMTgzNjYyNzYwMTE4MT...
# 2           2  /American-Tourister-AMT-SCH-02/dp/B07CJCGM1M/r...
# 3           3  /Wesley-Milestone-Waterproof-Backpack-Business...
# 4           4  /ADISA-Laptop-Backpack-Office-College/dp/B09TP...
# 5           5  /Skybags-Brat-Black-Casual-Backpack/dp/B08Z1HH...
# 6           6  /FUR-JADEN-Leatherette-Polypropylene-DUFF05/dp...
# 7           7  /Wesley-Milestone-Waterproof-Backpack-Business...
# 8           8  /Kleider-Travel-Business-Messenger-Shoulder/dp...
# 9           9  /Half-Moon-Waterproof-Backpack-Students/dp/B08...
#
#                                         Product_name Product_price  \
# 0  Tabelito® Volt Casual Waterproof Laptop Backpa...        5,590.
# 1  URBAN TRIBE Havana 15.6" inch Laptop Backpack ...        5,590.
# ...

# %%
df.shape
# Out:
# (6216, 6)

# %%
df.size
# Out:
# 37296

# %%
# Part 2

# %%
import cv2

# %%
product_info = []

# %%
for i in range(1,50):
    df["Product_url"] = "https://www.amazon.in" + df["Product_url"]
    url = df['Product_url'][i]
    headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
    response = requests.get(url, headers = headers)
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        description = soup.find('div', {'id': 'productDescription'}).text
        asin = soup.find('div', {'id': 'ASIN'}).text
        product_description = soup.find('div', {'id': 'productDescription'}).text
        manufacturer = soup.find('div', {'id': 'bylineInfo'}).text
        product = {
            'Description': description,
            'ASIN': asin,
            'Product Description': product_description,
            'Manufacturer': manufacturer
        }
        product_info.append(product)
with open('product_info.csv', 'w', newline='') as file:
    writer = csv.DictWriter(file, fieldnames=product.keys())
    writer.writeheader()
    writer.writerows(product_info)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     173         try:
# --> 174             conn = connection.create_connection(
#     175                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~\anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      71
# ---> 72     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      73         af, socktype, proto, canonname, sa = res
#
# ~\anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     953     addrlist = []
# --> 954     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     955         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# ...

# %%
# getting errors while hitting the url ...
